# %% [markdown]
# # ABSTRACTION
#
# Tìm length của subarray có giá trị min lớn hơn hoặc bằng số phần tử của subarray đó.
#
#
# # PARTERN RECOGNITION
#
# Brute Force
#
# Độ phức tạp: O(n)
#
# # ALGORITHM DESGIN
#
#     Input:
#         n (số nguyên): Số bài báo. (1 ≤ n ≤ 5×10^5)
#         c[] (số nguyên): mảng chứa chỉ số trích dẫn của từng bài báo (0 ≤ c[i] ≤ 10^6, i = 1 ÷ n)
#     Output:
#         H_index (số nguyên): Chỉ số H_index.
#     Temp:
#         i: biến đếm (0 ≤ i ≤ n-1).
#         temp (số nguyên): biến lưu số phần tử subarray ở mỗi vòng lặp. (initialize: temp=n-i)

# %% [markdown]
# ![H_index.png](attachment:H_index.png)

# %%
n = int(input())
c = list(map(int, input().split()))
c.sort() # Time: O(n)
H_index = 0


for i in range(n): # Time: O(n)
    temp = n - i
    if c[i] >= temp and (i < 1 or c[i - 1] <= temp):
        H_index = max(H_index, temp)

print(H_index)
# Out:
# 5
# 8 5 3 4 10
# 4
